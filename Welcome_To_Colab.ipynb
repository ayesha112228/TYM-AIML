# %% [markdown]
# <a href="https://colab.research.google.com/github/ayesha112228/TYM-AIML/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_excel('multiregression.xlsx')

# %%
dataset.head(3)
# Out:
#    Age  Experience  Salary
# 0   25           1   40000
# 1   30           5   58000
# 2   35           8   72000

# %%
dataset.isnull().sum()
# Out:
# Age           0
# Experience    0
# Salary        0
# dtype: int64

# %%
sns.pairplot(data=dataset)

# %%
sns.heatmap(data=dataset.corr(), annot=True)
plt.show()

# %%
x=dataset.iloc[:,:-1]

# %%
y=dataset["Salary"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,y_test, y_train, x_test =train_test_split(x,y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([1040.32258065, 3096.77419355])

# %%
lr.intercept_
# Out:
# np.float64(11205.64516129029)

# %%
lr.score(x_train,y_train)
# Out:
# 0.999511135328667
